# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
dataset = pd.read_csv('GOOGL.csv', index_col='Date', parse_dates=['Date'])

# %%
# Split the dataset into training and testing sets
train_set = dataset[:'2018'].iloc[:, 1:2].values
test_set = dataset['2019':].iloc[:, 1:2].values

# %%
# Normalize the dataset
sc = MinMaxScaler(feature_range=(0, 1))
train_set_scaled = sc.fit_transform(train_set)

# %%
# Create a function to generate a sliding window of data
def create_dataset(dataset, look_back=60):
    X, Y = [], []
    for i in range(look_back, len(dataset)):
        X.append(dataset[i-look_back:i, 0])
        Y.append(dataset[i, 0])
    X, Y = np.array(X), np.array(Y)
    X = np.reshape(X, (X.shape[0], X.shape[1], 1))
    return X, Y

# %%
# Generate the training and testing datasets
look_back = 60
X_train, Y_train = create_dataset(train_set_scaled, look_back)
X_test, Y_test = create_dataset(test_set, look_back)

# %%
# Build the RNN model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the RNN model
model.fit(X_train, Y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 112/112 [==============================] - 14s 71ms/step - loss: 0.0091
# Epoch 2/100
# 112/112 [==============================] - 10s 92ms/step - loss: 2.3923e-04
# Epoch 3/100
# 112/112 [==============================] - 9s 79ms/step - loss: 2.2965e-04
# Epoch 4/100
# 112/112 [==============================] - 11s 94ms/step - loss: 2.3552e-04
# Epoch 5/100
# 112/112 [==============================] - 12s 111ms/step - loss: 2.3164e-04
# Epoch 6/100
# 112/112 [==============================] - 7s 59ms/step - loss: 2.3587e-04
# Epoch 7/100
# 112/112 [==============================] - 8s 68ms/step - loss: 2.2504e-04
# Epoch 8/100
# 112/112 [==============================] - 8s 70ms/step - loss: 2.2990e-04
# Epoch 9/100
# 112/112 [==============================] - 6s 57ms/step - loss: 1.8855e-04
# Epoch 10/100
# 112/112 [==============================] - 8s 69ms/step - loss: 2.0127e-04
# Epoch 11/100
# 112/112 [==============================] - 7s 60ms/step - loss: 2.3821e-04
# Epoch 12/100
# 112/112 [==============================] - 8s 72ms/step - loss: 1.9406e-04
# Epoch 13/100
# 112/112 [==============================] - 7s 59ms/step - loss: 1.8141e-04
# Epoch 14/100
# 112/112 [==============================] - 7s 67ms/step - loss: 1.9073e-04
# Epoch 15/100
# 112/112 [==============================] - 7s 66ms/step - loss: 1.8316e-04
# Epoch 16/100
# 112/112 [==============================] - 7s 60ms/step - loss: 1.8556e-04
# Epoch 17/100
# 112/112 [==============================] - 7s 67ms/step - loss: 1.6133e-04
# Epoch 18/100
# 112/112 [==============================] - 7s 63ms/step - loss: 1.5685e-04
# Epoch 19/100
# 112/112 [==============================] - 8s 75ms/step - loss: 1.3999e-04
# Epoch 20/100
# 112/112 [==============================] - 7s 58ms/step - loss: 1.4980e-04
# Epoch 21/100
# 112/112 [==============================] - 8s 67ms/step - loss: 1.4769e-04
# Epoch 22/100
# 112/112 [==============================] - 8s 68ms/step - loss: 1.2224e-04
# Epoch 23/100
# 112/112 [==============================] - 7s 59ms/step - loss: 1.2040e-04
# Epoch 24/100
# 112/112 [==============================] - 8s 69ms/step - loss: 1.2246e-04
# Epoch 25/100
# 112/112 [==============================] - 14s 122ms/step - loss: 1.1658e-04
# Epoch 26/100
# 112/112 [==============================] - 7s 58ms/step - loss: 1.1322e-04
# Epoch 27/100
# 112/112 [==============================] - 8s 67ms/step - loss: 9.6923e-05
# Epoch 28/100
# 112/112 [==============================] - 6s 58ms/step - loss: 1.0604e-04
# Epoch 29/100
# 112/112 [==============================] - 8s 68ms/step - loss: 1.4775e-04
# Epoch 30/100
# 112/112 [==============================] - 7s 63ms/step - loss: 9.1461e-05
# Epoch 31/100
# 112/112 [==============================] - 7s 61ms/step - loss: 1.0527e-04
# Epoch 32/100
# 112/112 [==============================] - 8s 69ms/step - loss: 8.0179e-05
# Epoch 33/100
# 112/112 [==============================] - 7s 59ms/step - loss: 7.6025e-05
# Epoch 34/100
# 112/112 [==============================] - 8s 67ms/step - loss: 6.9863e-05
# Epoch 35/100
# 112/112 [==============================] - 6s 58ms/step - loss: 6.4882e-05
# Epoch 36/100
# 112/112 [==============================] - 8s 68ms/step - loss: 9.4396e-05
# Epoch 37/100
# 112/112 [==============================] - 7s 59ms/step - loss: 7.9602e-05
# Epoch 38/100
# 112/112 [==============================] - 7s 66ms/step - loss: 6.5335e-05
# Epoch 39/100
# 112/112 [==============================] - 8s 68ms/step - loss: 6.3869e-05
# Epoch 40/100
# 112/112 [==============================] - 7s 63ms/step - loss: 6.6519e-05
# Epoch 41/100
# 112/112 [==============================] - 7s 67ms/step - loss: 6.6642e-05
# Epoch 42/100
# 112/112 [==============================] - 6s 56ms/step - loss: 6.2887e-05
# Epoch 43/100
# 112/112 [==============================] - 9s 78ms/step - loss: 7.6414e-05
# Epoch 44/100
# 112/112 [==============================] - 6s 57ms/step - loss: 5.3578e-05
# Epoch 45/100
# 112/112 [==============================] - 8s 67ms/step - loss: 6.5451e-05
# Epoch 46/100
# 112/112 [==============================] - 7s 66ms/step - loss: 5.8136e-05
# Epoch 47/100
# 112/112 [==============================] - 7s 62ms/step - loss: 5.3315e-05
# Epoch 48/100
# 112/112 [==============================] - 8s 68ms/step - loss: 6.0784e-05
# Epoch 49/100
# 112/112 [==============================] - 6s 57ms/step - loss: 4.9349e-05
# Epoch 50/100
# 112/112 [==============================] - 8s 68ms/step - loss: 5.4268e-05
# Epoch 51/100
# 112/112 [==============================] - 7s 59ms/step - loss: 5.5443e-05
# Epoch 52/100
# 112/112 [==============================] - 8s 69ms/step - loss: 4.7842e-05
# Epoch 53/100
# 112/112 [==============================] - 6s 57ms/step - loss: 6.0611e-05
# Epoch 54/100
# 112/112 [==============================] - 7s 65ms/step - loss: 4.7273e-05
# Epoch 55/100
# 112/112 [==============================] - 7s 66ms/step - loss: 5.7889e-05
# Epoch 56/100
# 112/112 [==============================] - 7s 60ms/step - loss: 5.2863e-05
# Epoch 57/100
# 112/112 [==============================] - 8s 68ms/step - loss: 5.7162e-05
# Epoch 58/100
# 112/112 [==============================] - 6s 57ms/step - loss: 5.6393e-05
# Epoch 59/100
# 112/112 [==============================] - 8s 72ms/step - loss: 5.4760e-05
# Epoch 60/100
# 112/112 [==============================] - 7s 59ms/step - loss: 5.1849e-05
# Epoch 61/100
# 112/112 [==============================] - 8s 70ms/step - loss: 5.4310e-05
# Epoch 62/100
# 112/112 [==============================] - 7s 62ms/step - loss: 4.9681e-05
# Epoch 63/100
# 112/112 [==============================] - 7s 65ms/step - loss: 4.8735e-05
# Epoch 64/100
# 112/112 [==============================] - 8s 71ms/step - loss: 4.6906e-05
# Epoch 65/100
# 112/112 [==============================] - 9s 82ms/step - loss: 4.5986e-05
# Epoch 66/100
# 112/112 [==============================] - 8s 68ms/step - loss: 5.9184e-05
# Epoch 67/100
# 112/112 [==============================] - 8s 69ms/step - loss: 5.4038e-05
# Epoch 68/100
# 112/112 [==============================] - 7s 60ms/step - loss: 6.6976e-05
# Epoch 69/100
# 112/112 [==============================] - 8s 69ms/step - loss: 4.9411e-05
# Epoch 70/100
# 112/112 [==============================] - 7s 59ms/step - loss: 5.0016e-05
# Epoch 71/100
# 112/112 [==============================] - 8s 70ms/step - loss: 4.2861e-05
# Epoch 72/100
# 112/112 [==============================] - 7s 59ms/step - loss: 4.1775e-05
# Epoch 73/100
# 112/112 [==============================] - 8s 69ms/step - loss: 5.5867e-05
# Epoch 74/100
# 112/112 [==============================] - 7s 64ms/step - loss: 4.2521e-05
# Epoch 75/100
# 112/112 [==============================] - 7s 60ms/step - loss: 4.8698e-05
# Epoch 76/100
# 112/112 [==============================] - 7s 67ms/step - loss: 4.8095e-05
# Epoch 77/100
# 112/112 [==============================] - 7s 60ms/step - loss: 4.8404e-05
# Epoch 78/100
# 112/112 [==============================] - 8s 68ms/step - loss: 5.0311e-05
# Epoch 79/100
# 112/112 [==============================] - 6s 57ms/step - loss: 4.6712e-05
# Epoch 80/100
# 112/112 [==============================] - 8s 69ms/step - loss: 4.4673e-05
# Epoch 81/100
# 112/112 [==============================] - 7s 58ms/step - loss: 4.4682e-05
# Epoch 82/100
# 112/112 [==============================] - 8s 68ms/step - loss: 4.8277e-05
# Epoch 83/100
# 112/112 [==============================] - 7s 65ms/step - loss: 5.1698e-05
# Epoch 84/100
# 112/112 [==============================] - 7s 61ms/step - loss: 4.4701e-05
# Epoch 85/100
# 112/112 [==============================] - 8s 69ms/step - loss: 6.1148e-05
# Epoch 86/100
# 112/112 [==============================] - 7s 59ms/step - loss: 4.4526e-05
# Epoch 87/100
# 112/112 [==============================] - 8s 68ms/step - loss: 4.4504e-05
# Epoch 88/100
# 112/112 [==============================] - 7s 59ms/step - loss: 4.4409e-05
# Epoch 89/100
# 112/112 [==============================] - 8s 68ms/step - loss: 4.6194e-05
# Epoch 90/100
# 112/112 [==============================] - 7s 60ms/step - loss: 4.0631e-05
# Epoch 91/100
# 112/112 [==============================] - 7s 66ms/step - loss: 4.4562e-05
# Epoch 92/100
# 112/112 [==============================] - 8s 69ms/step - loss: 4.3445e-05
# Epoch 93/100
# 112/112 [==============================] - 6s 58ms/step - loss: 5.0540e-05
# Epoch 94/100
# 112/112 [==============================] - 8s 68ms/step - loss: 4.3939e-05
# Epoch 95/100
# 112/112 [==============================] - 6s 57ms/step - loss: 4.7355e-05
# Epoch 96/100
# 112/112 [==============================] - 8s 68ms/step - loss: 4.4530e-05
# Epoch 97/100
# 112/112 [==============================] - 6s 57ms/step - loss: 4.5926e-05
# Epoch 98/100
# 112/112 [==============================] - 8s 68ms/step - loss: 4.5380e-05
# Epoch 99/100
# 112/112 [==============================] - 7s 61ms/step - loss: 5.0987e-05
# Epoch 100/100
# 112/112 [==============================] - 7s 64ms/step - loss: 4.7924e-05

# %%
# Make predictions on future Google stock prices
last_60_days = train_set[-60:]
last_60_days_scaled = sc.transform(last_60_days)
X_pred = np.array([last_60_days_scaled])
X_pred = np.reshape(X_pred, (X_pred.shape[0], X_pred.shape[1], 1))
pred_price = model.predict(X_pred)
pred_price = sc.inverse_transform(pred_price)
print(pred_price)
# Out:
# 1/1 [==============================] - 1s 865ms/step
# [[1071.5663]]
